# %% [markdown]
# # Activating Your First Artificial Neuron

# %%
# Initial imports
import pandas as pd
import numpy as np
from sklearn.datasets import make_blobs, make_moons
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %matplotlib inline

# %% [markdown]
# ## Using a Single Neuron for Binary Classification
#
# ### Creating Dummy Data

# %%
# Generate 1000 demo data samples with 2 features and two centers
X, y = make_blobs(n_samples=1000, centers=2, n_features=2, random_state=78)

# %%
# Transforming y to a vertical vector
y = y.reshape(-1, 1)
y.shape
# Out:
# (1000, 1)

# %%
# Creating a DataFrame with the dummy data
df = pd.DataFrame(X, columns=["Feature 1", "Feature 2"])
df["Target"] = y
df.head()
# Out:
#    Feature 1  Feature 2  Target
# 0   5.478098   7.203714       1
# 1  -8.428483   4.121889       0
# 2  -7.905447   3.323639       0
# 3   6.411041   5.523013       1
# 4   7.288599   6.171226       1

# %%
# Plotting the dummy data
df.plot.scatter(x="Feature 1", y="Feature 2", c="Target", colormap="winter")
# Out:
# <AxesSubplot:xlabel='Feature 1', ylabel='Feature 2'>

# %% [markdown]
#  ### Data Preprocessing
#
#  Use `train_test_split` to create training and testing data.

# %%
# Create training and testing datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %% [markdown]
#  Scale the data using the `StandarScaler`.

# %%
# Create scaler instance
X_scaler = StandardScaler()

# %%
# Fit the scaler
X_scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
#  ### Neural Network Model Creation

# %%
# Create a sequential model
neuron = Sequential()

# %% [markdown]
# The initial step is to add the first layer of our neural network.
#
# ![First Layer](../Images/tensorflow-neuron-layer-1.png)

# %%
# First layer
number_inputs = 2
number_hidden_nodes = 1

neuron.add(Dense(units=number_hidden_nodes, activation="relu", input_dim=number_inputs))

# %% [markdown]
# We finish creating our neural network by adding the output layer.
#
# ![Output layer](../Images/tensorflow-neuron-output-layer.png)

# %%
# Output layer
number_classes = 1

neuron.add(Dense(units=number_classes, activation="sigmoid"))

# %%
# Model summary
neuron.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 3
#
#  dense_1 (Dense)             (None, 1)                 2
#
# =================================================================
# Total params: 5
# Trainable params: 5
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
#  ### Compile the Model

# %%
# Compile model
neuron.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %% [markdown]
#  ### Fit the Model

# %%
# Fitting the model with linear dummy data
model = neuron.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 1s 2ms/step - loss: 0.5664 - accuracy: 1.0000
# Epoch 2/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5538 - accuracy: 1.0000
# Epoch 3/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5411 - accuracy: 1.0000
# Epoch 4/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5282 - accuracy: 1.0000
# Epoch 5/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5154 - accuracy: 1.0000
# Epoch 6/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.5024 - accuracy: 1.0000
# Epoch 7/100
# 24/24 [==============================] - 0s 8ms/step - loss: 0.4895 - accuracy: 1.0000
# Epoch 8/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.4767 - accuracy: 1.0000
# Epoch 9/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4640 - accuracy: 0.9987
# Epoch 10/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4515 - accuracy: 0.9987
# Epoch 11/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4392 - accuracy: 0.9987
# Epoch 12/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4273 - accuracy: 0.9987
# Epoch 13/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4156 - accuracy: 0.9987
# Epoch 14/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4043 - accuracy: 0.9987
# Epoch 15/100
# 24/24 [==============================] - 0s 7ms/step - loss: 0.3933 - accuracy: 0.9987
# Epoch 16/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3826 - accuracy: 0.9987
# Epoch 17/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3722 - accuracy: 0.9987
# Epoch 18/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3622 - accuracy: 0.9987
# Epoch 19/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3525 - accuracy: 1.0000
# Epoch 20/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3431 - accuracy: 1.0000
# Epoch 21/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3341 - accuracy: 1.0000
# Epoch 22/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3254 - accuracy: 1.0000
# Epoch 23/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3170 - accuracy: 1.0000
# Epoch 24/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3089 - accuracy: 1.0000
# Epoch 25/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3010 - accuracy: 1.0000
# Epoch 26/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2934 - accuracy: 1.0000
# Epoch 27/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2862 - accuracy: 1.0000
# Epoch 28/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2791 - accuracy: 1.0000
# Epoch 29/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2723 - accuracy: 1.0000
# Epoch 30/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2657 - accuracy: 1.0000
# Epoch 31/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.2594 - accuracy: 1.0000
# Epoch 32/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2533 - accuracy: 1.0000
# Epoch 33/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2474 - accuracy: 1.0000
# Epoch 34/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2417 - accuracy: 1.0000
# Epoch 35/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2361 - accuracy: 1.0000
# Epoch 36/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2308 - accuracy: 1.0000
# Epoch 37/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2256 - accuracy: 1.0000
# Epoch 38/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2206 - accuracy: 1.0000
# Epoch 39/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2157 - accuracy: 1.0000
# Epoch 40/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2110 - accuracy: 1.0000
# Epoch 41/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2064 - accuracy: 1.0000
# Epoch 42/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2020 - accuracy: 1.0000
# Epoch 43/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1977 - accuracy: 1.0000
# Epoch 44/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1936 - accuracy: 1.0000
# Epoch 45/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1895 - accuracy: 1.0000
# Epoch 46/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1856 - accuracy: 1.0000
# Epoch 47/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1818 - accuracy: 1.0000
# Epoch 48/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1781 - accuracy: 1.0000
# Epoch 49/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1746 - accuracy: 1.0000
# Epoch 50/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1711 - accuracy: 1.0000
# Epoch 51/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1677 - accuracy: 1.0000
# Epoch 52/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1644 - accuracy: 1.0000
# Epoch 53/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1612 - accuracy: 1.0000
# Epoch 54/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1581 - accuracy: 1.0000
# Epoch 55/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1550 - accuracy: 1.0000
# Epoch 56/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1520 - accuracy: 1.0000
# Epoch 57/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1492 - accuracy: 1.0000
# Epoch 58/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1464 - accuracy: 1.0000
# Epoch 59/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1436 - accuracy: 1.0000
# Epoch 60/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1409 - accuracy: 1.0000
# Epoch 61/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1383 - accuracy: 1.0000
# Epoch 62/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1358 - accuracy: 1.0000
# Epoch 63/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1333 - accuracy: 1.0000
# Epoch 64/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1309 - accuracy: 1.0000
# Epoch 65/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1285 - accuracy: 1.0000
# Epoch 66/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1263 - accuracy: 1.0000
# Epoch 67/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1240 - accuracy: 1.0000
# Epoch 68/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1218 - accuracy: 1.0000
# Epoch 69/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1197 - accuracy: 1.0000
# Epoch 70/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1176 - accuracy: 1.0000
# Epoch 71/100
# 24/24 [==============================] - 0s 8ms/step - loss: 0.1155 - accuracy: 1.0000
# Epoch 72/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1136 - accuracy: 1.0000
# Epoch 73/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1116 - accuracy: 1.0000
# Epoch 74/100
# 24/24 [==============================] - 0s 7ms/step - loss: 0.1097 - accuracy: 1.0000
# Epoch 75/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1079 - accuracy: 1.0000
# Epoch 76/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1060 - accuracy: 1.0000
# Epoch 77/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1043 - accuracy: 1.0000
# Epoch 78/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1025 - accuracy: 1.0000
# Epoch 79/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1008 - accuracy: 1.0000
# Epoch 80/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0992 - accuracy: 1.0000
# Epoch 81/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0976 - accuracy: 1.0000
# Epoch 82/100
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0960 - accuracy: 1.0000
# Epoch 83/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0944 - accuracy: 1.0000
# Epoch 84/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0929 - accuracy: 1.0000
# Epoch 85/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0914 - accuracy: 1.0000
# Epoch 86/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0900 - accuracy: 1.0000
# Epoch 87/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0886 - accuracy: 1.0000
# Epoch 88/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0871 - accuracy: 1.0000
# Epoch 89/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0858 - accuracy: 1.0000
# Epoch 90/100
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0844 - accuracy: 1.0000
# Epoch 91/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0831 - accuracy: 1.0000
# Epoch 92/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0818 - accuracy: 1.0000
# Epoch 93/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0806 - accuracy: 1.0000
# Epoch 94/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.0793 - accuracy: 1.0000
# Epoch 95/100
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0781 - accuracy: 1.0000
# Epoch 96/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0769 - accuracy: 1.0000
# Epoch 97/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0758 - accuracy: 1.0000
# Epoch 98/100
# 24/24 [==============================] - 0s 12ms/step - loss: 0.0746 - accuracy: 1.0000
# Epoch 99/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.0735 - accuracy: 1.0000
# Epoch 100/100
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0724 - accuracy: 1.0000

# %% [markdown]
#  ### Evaluate the Model
#
#  #### Plotting the Loss Function and Accuracy

# %%
# Create a DataFrame with the history dictionary
df = pd.DataFrame(model.history, index=range(1, len(model.history["loss"]) + 1))

# Plot the loss
df.plot(y="loss")
# Out:
# <AxesSubplot:>

# %%
# Plot the accuracy
df.plot(y="accuracy")
# Out:
# <AxesSubplot:>

# %% [markdown]
#  #### Evaluating the Model Using Testing Data

# %%
# Evaluate the model fit with linear dummy data
model_loss, model_accuracy = neuron.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 8/8 - 0s - loss: 0.0673 - accuracy: 1.0000 - 383ms/epoch - 48ms/step
# Loss: 0.06734440475702286, Accuracy: 1.0

# %% [markdown]
#  ### Making Predictions with New Data

# %%
# Create 10 new samples of dummy data
new_X, new_y = make_blobs(n_samples=10, centers=2, n_features=2, random_state=78)

# %%
# Making predictions
predictions = (neuron.predict(new_X) > 0.5).astype("int32")
results = pd.DataFrame({"predictions": predictions.ravel(), "actual": new_y})
results.head(10)
# Out:
# 1/1 [==============================] - 0s 275ms/step
#    predictions  actual
# 0            0       0
# 1            1       1
# 2            0       0
# 3            1       1
# 4            0       0
# 5            0       0
# 6            1       1
# 7            1       1
# 8            1       1
# 9            0       0

# %% [markdown]
# ---

# %% [markdown]
# # Using a Single Neuron for Non-Linear Data
#
# ### Creating Demo Data:

# %%
# Creating dummy non-linear data
X_moons, y_moons = make_moons(n_samples=1000, noise=0.08, random_state=78)

# %%
# Transforming y_moons to a vertical vector
y_moons = y_moons.reshape(-1, 1)

# %%
# Creating a DataFrame to plot the non-linear dummy data
df_moons = pd.DataFrame(X_moons, columns=["Feature 1", "Feature 2"])
df_moons["Target"] = y_moons
df_moons.head()
# Out:
#    Feature 1  Feature 2  Target
# 0   0.676217   0.815220       0
# 1   1.487143  -0.210519       1
# 2  -1.027709   0.354966       0
# 3   0.236012   1.025531       0
# 4   1.856695  -0.042783       1

# %%
# Plotting the non-linear dummy data
df_moons.plot.scatter(x="Feature 1", y="Feature 2", c="Target", colormap="summer")
# Out:
# <AxesSubplot:xlabel='Feature 1', ylabel='Feature 2'>

# %% [markdown]
# ### Data Preprocessing
#
# Use `train_test_split` to create training and testing data.

# %%
# Create training and testing sets
X_moon_train, X_moon_test, y_moon_train, y_moon_test = train_test_split(
    X_moons, y_moons, random_state=78
)

# %% [markdown]
#  Scale the data

# %%
# Create the scaler instance
X_moon_scaler = StandardScaler()

# %%
# Fit the scaler
X_moon_scaler.fit(X_moon_train)
# Out:
# StandardScaler()

# %%
# Scale the data
X_moon_train_scaled = X_moon_scaler.transform(X_moon_train)
X_moon_test_scaled = X_moon_scaler.transform(X_moon_test)

# %% [markdown]
#  ### Fit the Model

# %%
# Training the model with the non-linear data
model_moon = neuron.fit(X_moon_train_scaled, y_moon_train, epochs=100)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 4s 22ms/step - loss: 1.1665 - accuracy: 0.4573
# Epoch 2/100
# 24/24 [==============================] - 1s 24ms/step - loss: 1.0389 - accuracy: 0.4733
# Epoch 3/100
# 24/24 [==============================] - 1s 24ms/step - loss: 0.9532 - accuracy: 0.4907
# Epoch 4/100
# 24/24 [==============================] - 1s 22ms/step - loss: 0.8975 - accuracy: 0.5080
# Epoch 5/100
# 24/24 [==============================] - 1s 23ms/step - loss: 0.8567 - accuracy: 0.5240
# Epoch 6/100
# 24/24 [==============================] - 1s 22ms/step - loss: 0.8253 - accuracy: 0.5387
# Epoch 7/100
# 24/24 [==============================] - 1s 23ms/step - loss: 0.8003 - accuracy: 0.5480
# Epoch 8/100
# 24/24 [==============================] - 1s 25ms/step - loss: 0.7790 - accuracy: 0.5600
# Epoch 9/100
# 24/24 [==============================] - 1s 23ms/step - loss: 0.7609 - accuracy: 0.5720
# Epoch 10/100
# 24/24 [==============================] - 1s 26ms/step - loss: 0.7454 - accuracy: 0.5787
# Epoch 11/100
# 24/24 [==============================] - 1s 25ms/step - loss: 0.7315 - accuracy: 0.5880
# Epoch 12/100
# 24/24 [==============================] - 1s 26ms/step - loss: 0.7192 - accuracy: 0.5960
# Epoch 13/100
# 24/24 [==============================] - 1s 25ms/step - loss: 0.7079 - accuracy: 0.5987
# Epoch 14/100
# 24/24 [==============================] - 0s 17ms/step - loss: 0.6975 - accuracy: 0.6067
# Epoch 15/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.6880 - accuracy: 0.6120
# Epoch 16/100
# 24/24 [==============================] - 0s 9ms/step - loss: 0.6790 - accuracy: 0.6187
# Epoch 17/100
# 24/24 [==============================] - 0s 9ms/step - loss: 0.6708 - accuracy: 0.6253
# Epoch 18/100
# 24/24 [==============================] - 0s 8ms/step - loss: 0.6631 - accuracy: 0.6267
# Epoch 19/100
# 24/24 [==============================] - 0s 11ms/step - loss: 0.6558 - accuracy: 0.6320
# Epoch 20/100
# 24/24 [==============================] - 0s 11ms/step - loss: 0.6490 - accuracy: 0.6333
# Epoch 21/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.6423 - accuracy: 0.6387
# Epoch 22/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.6363 - accuracy: 0.6427
# Epoch 23/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6301 - accuracy: 0.6520
# Epoch 24/100
# 24/24 [==============================] - 0s 7ms/step - loss: 0.6242 - accuracy: 0.6547
# Epoch 25/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6188 - accuracy: 0.6547
# Epoch 26/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.6135 - accuracy: 0.6573
# Epoch 27/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.6083 - accuracy: 0.6600
# Epoch 28/100
# 24/24 [==============================] - 0s 10ms/step - loss: 0.6033 - accuracy: 0.6627
# Epoch 29/100
# 24/24 [==============================] - 0s 16ms/step - loss: 0.5987 - accuracy: 0.6627
# Epoch 30/100
# 24/24 [==============================] - 0s 12ms/step - loss: 0.5940 - accuracy: 0.6667
# Epoch 31/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.5897 - accuracy: 0.6707
# Epoch 32/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.5853 - accuracy: 0.6747
# Epoch 33/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.5813 - accuracy: 0.6760
# Epoch 34/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.5774 - accuracy: 0.6773
# Epoch 35/100
# 24/24 [==============================] - 0s 8ms/step - loss: 0.5736 - accuracy: 0.6760
# Epoch 36/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.5701 - accuracy: 0.6760
# Epoch 37/100
# 24/24 [==============================] - 0s 10ms/step - loss: 0.5664 - accuracy: 0.6787
# Epoch 38/100
# 24/24 [==============================] - 0s 7ms/step - loss: 0.5630 - accuracy: 0.6787
# Epoch 39/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.5595 - accuracy: 0.6800
# Epoch 40/100
# 24/24 [==============================] - 0s 14ms/step - loss: 0.5562 - accuracy: 0.6827
# Epoch 41/100
# 24/24 [==============================] - 0s 11ms/step - loss: 0.5530 - accuracy: 0.6867
# Epoch 42/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.5501 - accuracy: 0.6867
# Epoch 43/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.5470 - accuracy: 0.6893
# Epoch 44/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5440 - accuracy: 0.6933
# Epoch 45/100
# 24/24 [==============================] - 0s 8ms/step - loss: 0.5410 - accuracy: 0.6947
# Epoch 46/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.5381 - accuracy: 0.6973
# Epoch 47/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5353 - accuracy: 0.6987
# Epoch 48/100
# 24/24 [==============================] - 0s 9ms/step - loss: 0.5325 - accuracy: 0.7000
# Epoch 49/100
# 24/24 [==============================] - 0s 7ms/step - loss: 0.5297 - accuracy: 0.7000
# Epoch 50/100
# 24/24 [==============================] - 0s 8ms/step - loss: 0.5272 - accuracy: 0.7053
# Epoch 51/100
# 24/24 [==============================] - 0s 8ms/step - loss: 0.5244 - accuracy: 0.7080
# Epoch 52/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.5219 - accuracy: 0.7107
# Epoch 53/100
# 24/24 [==============================] - 0s 8ms/step - loss: 0.5193 - accuracy: 0.7107
# Epoch 54/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.5168 - accuracy: 0.7147
# Epoch 55/100
# 24/24 [==============================] - 0s 8ms/step - loss: 0.5142 - accuracy: 0.7160
# Epoch 56/100
# 24/24 [==============================] - 0s 10ms/step - loss: 0.5118 - accuracy: 0.7187
# Epoch 57/100
# 24/24 [==============================] - 0s 10ms/step - loss: 0.5093 - accuracy: 0.7200
# Epoch 58/100
# 24/24 [==============================] - 0s 8ms/step - loss: 0.5067 - accuracy: 0.7200
# Epoch 59/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5041 - accuracy: 0.7213
# Epoch 60/100
# 24/24 [==============================] - 0s 12ms/step - loss: 0.5015 - accuracy: 0.7227
# Epoch 61/100
# 24/24 [==============================] - 0s 8ms/step - loss: 0.4990 - accuracy: 0.7240
# Epoch 62/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.4965 - accuracy: 0.7253
# Epoch 63/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.4941 - accuracy: 0.7267
# Epoch 64/100
# 24/24 [==============================] - 0s 9ms/step - loss: 0.4915 - accuracy: 0.7307
# Epoch 65/100
# 24/24 [==============================] - 0s 17ms/step - loss: 0.4889 - accuracy: 0.7333
# Epoch 66/100
# 24/24 [==============================] - 0s 17ms/step - loss: 0.4863 - accuracy: 0.7347
# Epoch 67/100
# 24/24 [==============================] - 0s 13ms/step - loss: 0.4836 - accuracy: 0.7347
# Epoch 68/100
# 24/24 [==============================] - 0s 8ms/step - loss: 0.4811 - accuracy: 0.7347
# Epoch 69/100
# 24/24 [==============================] - 0s 9ms/step - loss: 0.4783 - accuracy: 0.7387
# Epoch 70/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4757 - accuracy: 0.7440
# Epoch 71/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.4730 - accuracy: 0.7453
# Epoch 72/100
# 24/24 [==============================] - 0s 6ms/step - loss: 0.4704 - accuracy: 0.7480
# Epoch 73/100
# 24/24 [==============================] - 0s 9ms/step - loss: 0.4677 - accuracy: 0.7520
# Epoch 74/100
# 24/24 [==============================] - 0s 7ms/step - loss: 0.4650 - accuracy: 0.7520
# Epoch 75/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4622 - accuracy: 0.7547
# Epoch 76/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4594 - accuracy: 0.7560
# Epoch 77/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4563 - accuracy: 0.7587
# Epoch 78/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.4532 - accuracy: 0.7587
# Epoch 79/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4501 - accuracy: 0.7613
# Epoch 80/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4471 - accuracy: 0.7653
# Epoch 81/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4442 - accuracy: 0.7667
# Epoch 82/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4411 - accuracy: 0.7667
# Epoch 83/100
# 24/24 [==============================] - 0s 9ms/step - loss: 0.4381 - accuracy: 0.7707
# Epoch 84/100
# 24/24 [==============================] - 0s 9ms/step - loss: 0.4351 - accuracy: 0.7747
# Epoch 85/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.4322 - accuracy: 0.7760
# Epoch 86/100
# 24/24 [==============================] - 0s 9ms/step - loss: 0.4290 - accuracy: 0.7800
# Epoch 87/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4259 - accuracy: 0.7827
# Epoch 88/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4227 - accuracy: 0.7853
# Epoch 89/100
# 24/24 [==============================] - 0s 5ms/step - loss: 0.4196 - accuracy: 0.7853
# Epoch 90/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4165 - accuracy: 0.7893
# Epoch 91/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4133 - accuracy: 0.7947
# Epoch 92/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4102 - accuracy: 0.8013
# Epoch 93/100
# 24/24 [==============================] - 0s 7ms/step - loss: 0.4071 - accuracy: 0.8027
# Epoch 94/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4040 - accuracy: 0.8040
# Epoch 95/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4009 - accuracy: 0.8053
# Epoch 96/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3977 - accuracy: 0.8053
# Epoch 97/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3945 - accuracy: 0.8080
# Epoch 98/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3914 - accuracy: 0.8107
# Epoch 99/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3882 - accuracy: 0.8107
# Epoch 100/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3850 - accuracy: 0.8133

# %% [markdown]
#  ### Evaluate the Model
#
#  #### Plotting the Loss Function and Accuracy

# %%
# Create a DataFrame with the history dictionary
df_moon = pd.DataFrame(
    model_moon.history, index=range(1, len(model_moon.history["loss"]) + 1)
)

# Plot the loss
df_moon.plot(y="loss")
# Out:
# <AxesSubplot:>

# %%
# Plot the accuracy
df_moon.plot(y="accuracy")
# Out:
# <AxesSubplot:>

# %% [markdown]
#  #### Evaluating the Model Using Testing Data

# %%
# Evaluate the model using non-linear data
model_moon_loss, model_moon_accuracy = neuron.evaluate(
    X_moon_test_scaled, y_moon_test, verbose=2
)
print(f"Loss: {model_moon_loss}, Accuracy: {model_moon_accuracy}")
# Out:
# 8/8 - 0s - loss: 0.4004 - accuracy: 0.8080 - 252ms/epoch - 31ms/step
# Loss: 0.40042412281036377, Accuracy: 0.8080000281333923

# %% [markdown]
#  ### Making Predictions

# %%
# Create demo data
X_new_moons, y_new_moons = make_moons(n_samples=10, noise=0.08, random_state=78)

# %%
# Making predictions
predictions_moon = (neuron.predict(X_new_moons) > 0.5).astype("int32")

results = pd.DataFrame({"predictions": predictions_moon.ravel(), "actual": y_new_moons})
results.head(10)
# Out:
# 1/1 [==============================] - 0s 53ms/step
#    predictions  actual
# 0            0       0
# 1            0       0
# 2            0       0
# 3            1       1
# 4            1       1
# 5            0       0
# 6            1       0
# 7            1       1
# 8            1       1
# 9            0       1
